# %%
import pandas as pd

# %%
ds_file ='foo.txt'
ds_file = 'RAIS_VINC_PUB_NORTE.txt'
df = pd.read_csv(ds_file, encoding='latin1', sep=';')

# %%
df.shape
# Out:
# (9999, 62)

# %%
df.head()
# Out:
#              Bairros SP     Bairros Fortaleza            Bairros RJ  \
# 0             {ñ class}             {ñ class}             {ñ class}
# 1             {ñ class}             {ñ class}             {ñ class}
# 2             {ñ class}             {ñ class}             {ñ class}
# 3             {ñ class}             {ñ class}             {ñ class}
# 4             {ñ class}             {ñ class}             {ñ class}
#
#    Causa Afastamento 1  Causa Afastamento 2  Causa Afastamento 3  \
# 0                   99                   99                   99
# 1                   99                   99                   99
# 2                   99                   99                   99
# 3                   99                   99                   99
# 4                   99                   99                   99
#
#    Motivo Desligamento CBO Ocupação 2002  CNAE 2.0 Classe  CNAE 95 Classe  \
# 0                   11            711405             7227           13226
# ...
